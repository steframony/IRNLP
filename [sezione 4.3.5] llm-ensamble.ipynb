# %% [markdown]
# # Ensamble of Models
#
# Per valutare le performance del task di conversione in FOL, è stato scelto di costruire un task ad hoc in cui è stato utilizzato un ensemble di tre modelli, in particolare:
#
# 1. Meta meta-llama/Llama-3.1-8B-Instruct
# 2. Alibaba Cloud Qwen/Qwen2.5-7B-Instruct
# 3. Mistral mistralai/Mistral-7B-Instruct-v0.3
#
# Si è previsto due tipi di ensamble, in particolare:
#
# ![ensamble1](pics_notebook\ensamble_mod_1.jpg)
#
# I modelli giudici dopo aver fornito il loro responso, viene calcolata l’accuracy per ogni singolo
# giudice e ne viene fatta la media.
#
# ![ensamble2](pics_notebook\ensamble_mod_2.jpg)
#
# Nella quale, si differenzia dalla prima dopo aver calcolato i rispettivi output, si procede a
# selezionare l’output maggioritario, e si valuta l’accuracy su quest’ultima nuova aggregazione.

# %%
#####################################
# IMPORTING LIBRERIE
#####################################
import pandas as pd
import numpy as np
from datasets import load_dataset, Dataset
import matplotlib.pyplot as plt
import string

# %%
DATASET_gemma = "stefra/gemma_judge_final"
DATASET_llama = "stefra/llama_judge_final"
DATASET_qwen = "stefra/qwen_judge_final"
dataset_g = load_dataset(DATASET_gemma, split="train").to_pandas()
dataset_l = load_dataset(DATASET_llama, split="train").to_pandas()
dataset_q = load_dataset(DATASET_qwen, split="train").to_pandas()
# Out:
# README.md:   0%|          | 0.00/457 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/171k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1000 [00:00<?, ? examples/s]
# README.md:   0%|          | 0.00/457 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/173k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1000 [00:00<?, ? examples/s]
# README.md:   0%|          | 0.00/457 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/175k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
print(dataset_g['judge_mistral'].value_counts())
print("_"*40)
print(dataset_l['judge_mistral'].value_counts())
print("_"*40)
print(dataset_q['judge_mistral'].value_counts())
# Out:
# judge_mistral
# Yes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          941
# No                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            41
# Yes (the candidate FOL is logically equivalent to the true FOL)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                3
# Yes (for the candidate FOL)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    2
# No, the candidate FOL is not logically equivalent to the given sentence. The correct FOL should express that the braking distance depends on both the vehicle's speed and the road's surface condition, not just the vehicle and a combination of the two properties.\n\nCorrect FOL: ∀x∀y∀z (Vehicle(x) ∧ Speed(y) ∧ RoadSurfaceCondition(z) → DependsOnBrakingDistance(x, y, z))                                                                                                                                                                                                                                             1
# No\n\nThe candidate FOL formula "∀x (Teacher(x) → EducatesStudents(x))" is not logically equivalent to the natural language sentence "Teachers educate students in schools." The candidate FOL formula states that every teacher educates students, but it does not specify that the education takes place in a school. The true FOL formula should include a school as a parameter in the EducatesIn predicate to correctly represent the given sentence.                                                                                                                                                                     1
# No. The candidate FOL uses the universal quantifier (∀) instead of the existential quantifier (∃) in the fourth clause, which is not logically equivalent to the natural language sentence. The correct FOL should be: ∃x (Building(x) ∧ Tall(x) ∧ RedWalls(x) ∧ ManyWindows(x)).                                                                                                                                                                                                                                                                                                                                              1
# No\n\nThe candidate FOL formula is not logically equivalent to the natural language sentence. The candidate FOL formula implies that if an orchestra performs classical, jazz, and film scores, then it is versatile. However, the natural language sentence also requires that the orchestra can perform a "wide range" of musical styles, not just classical, jazz, and film scores. Therefore, the orchestra could be versatile even if it can perform other musical styles not mentioned in the candidate FOL formula.                                                                                                     1
# No\n\nThe candidate FOL formula does not correctly capture the relationship between rivers and lakes. It does not state that rivers flow into larger bodies of water, and it does not state that lakes are often fed by rivers or streams.                                                                                                                                                                                                                                                                                                                                                                                     1
# Yes (for the True FOL)\nNo (for the Candidate FOL)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# No, the candidate FOL is not logically equivalent to the given sentence. The candidate FOL states that every student reads a book that is in the library, which is not the same as stating that a student reads a book in a library. The correct FOL for the given sentence should be: ∀x∀y∀z (Student(x) ∧ Book(y) ∧ Library(z) → Reads(x, y, z))                                                                                                                                                                                                                                                                             1
# No, the candidate FOL is not logically equivalent to the given sentence. The candidate FOL states that all fabrics are breathable and not stain-resistant, suitable for sensitive skin, or machine washable, which is a stronger claim than the original sentence. The original sentence implies that some fabrics are breathable but not all fabrics have the other properties, while the candidate FOL states that no fabrics have the other properties.                                                                                                                                                                     1
# Yes (both are logically equivalent)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# Yes (both the true FOL and the candidate FOL are logically equivalent)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         1
# No, the candidate FOL is not logically equivalent to the given sentence. The candidate FOL incorrectly states that pollination is the male and female parts of a flower, which is not the case. The correct FOL should maintain the structure of the sentence, where pollination involves the transfer of pollen from the male part to the female part.\n\nCorrected Candidate FOL: ∀x∀y∀z (Pollination(x) ∧ MalePartOfFlower(y) ∧ FemalePartOfFlower(z) → (TransferOfPollen(x, y, z))) ∧ (EnablesFertilization(x) ∧ ProductionOfSeeds(x))\n\nThis corrected candidate FOL is logically equivalent to the given sentence.      1
# No\n\nThe candidate FOL formula only states that if something is public transportation, then it is either a bus, train, or subway. It does not express that public transportation provides an efficient and affordable means for commuters to travel, which is the main point in the natural language sentence. The correct FOL formula should include a relation between public transportation, commuters, and the property of providing an efficient and affordable means of travel.                                                                                                                                         1
# Yes (for both the True FOL and the Candidate FOL)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# Name: count, dtype: int64
# ________________________________________
# judge_mistral
# Yes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              959
# No                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                24
# Yes (for the Candidate FOL)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        3
# Yes (the candidate FOL is logically equivalent to the true FOL)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    2
# Yes (for the candidate FOL)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        2
# Yes (The candidate FOL is logically equivalent to the true FOL, although not identical.)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# No, the candidate FOL is not logically equivalent to the given sentence. The correct FOL should include individual variables for Tom, Lisa, and Mike, as in the example provided. The candidate FOL only states that if one person is taller than another and the other is shorter than a third, then the first is taller than the third, which is not the same as the original sentence.                                                                                                                                                                                                                                                                                                                                                                                                                          1
# No, the candidate FOL is not logically equivalent to the given sentence. The correct FOL should use the existential quantifier (∃) instead of the universal quantifier (∀) to express that there is at least one store that sells clothing, accessories, and footwear.\n\nCorrect FOL: ∃x (Store(x) ∧ SellsClothing(x) ∧ SellsAccessories(x) ∧ SellsFootwear(x))                                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# No, the candidate FOL is not logically equivalent to the given sentence. The candidate FOL states that for all buildings that are not homes, they are made of brick or wood, which is not the same as there being buildings that are not homes and made of brick or wood. The correct FOL for the given sentence is ∃x (Building(x) ∧ ¬Home(x) ∧ (MadeOfBrick(x) ∨ MadeOfWood(x)) as stated in the example.                                                                                                                                                                                                                                                                                                                                                                                                        1
# No\n\nThe candidate FOL formula is not logically equivalent to the natural language sentence. A correct FOL formula for the given sentence could be:\n\n∃x Dessert(x) ∧ ∃y Dessert(y) ∧ (Sweet(x) ∧ Cold(x) ∨ Savory(x) ∧ Warm(x)) ∧ (Sweet(y) ∧ Warm(y) ∨ Savory(y) ∧ Cold(y)) ∧ ∀x ∀y ((Dessert(x) ∧ Dessert(y) ∧ x ≠ y) → (¬(Sweet(x) ∧ Cold(x)) ∨ ¬(Sweet(y) ∧ Warm(y))))\n\nThis formula states that there exist at least two desserts, some are sweet and cold, some are savory and warm, and no two desserts can be both sweet and cold or both sweet and warm.                                                                                                                                                                                                                                             1
# No, the candidate FOL is not logically equivalent to the given sentence. The candidate FOL implies that if something is a bird, it can fly long distances, sing melodiously, and display colorful plumage, and this property is true for a specific bird species. However, the original sentence does not imply that these properties are unique to a specific bird species. Instead, it suggests that some birds (not all) have these properties. Therefore, the correct FOL would be:\n\n∃x (Bird(x) ∧ FlyLongDistances(x) ∧ SingMelodiously(x) ∧ ColorfulPlumage(x))\n\nThis FOL formula states that there exists an x such that x is a bird, and x has the properties of flying long distances, singing melodiously, and displaying colorful plumage. This is logically equivalent to the given sentence.      1
# No. The candidate FOL is not logically equivalent to the given sentence. The correct FOL for the sentence "Mars is a planet" is indeed Planet(mars). The candidate FOL, ∀x (Planet(x) → Mars(x)), is a universal implication, which states that if something is a planet, then it is Mars, which is not the same as saying Mars is a planet.                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# No. The candidate FOL is not logically equivalent to the given sentence. The correct FOL should be: ∀x (Pen(x) ⇒ (Refillable(x) ∧ RetractableTip(x)))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# No\n\nThe correct FOL for the sentence "Not all trees lose their leaves in autumn" is: ¬∀x (Tree(x) ∧ LosesLeavesInAutumn(x))\n\nThe candidate FOL you provided, ∀x (Tree(x) ∧ LosesLeavesInAutumn(x) → NotAllTrees(x)), is not logically equivalent to the given sentence. The candidate FOL states that if a tree loses its leaves in autumn, then it is not all trees, which is not the same as saying not all trees lose their leaves in autumn.                                                                                                                                                                                                                                                                                                                                                               1
# No, the candidate FOL is not logically equivalent to the given sentence. The candidate FOL states that every book is either valid (fiction, non-fiction, or biography) or invalid, which is not the case in the natural language sentence. The correct FOL should allow for some books to be fiction, some non-fiction, and some biographies, as stated in the example.                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# Name: count, dtype: int64
# ________________________________________
# judge_mistral
# Yes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    978
# No                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       7
# Yes (for the candidate FOL)                                                                                                                                                                                                                                                                                                                                                                                                                                                              2
# Yes (both the true FOL and the candidate FOL are logically equivalent)                                                                                                                                                                                                                                                                                                                                                                                                                   1
# Yes (the candidate FOL is logically equivalent to the true FOL)                                                                                                                                                                                                                                                                                                                                                                                                                          1
# No, the candidate FOL is not logically equivalent to the given sentence. The correct FOL should be: ∀x ∀y (Lion(x) ∧ Cow(y) → Carnivore(x) ∧ ¬Herbivore(y)) or ∀x ∀y (Cow(x) ∧ Lion(y) → Herbivore(x) ∧ ¬Carnivore(y)).                                                                                                                                                                                                                                                                  1
# Yes, the candidate FOL is logically equivalent to the true FOL:\n\nCandidate FOL: ∀x (Device(x) ∧ UsesMicrowaveRadiation(x) ∧ HeatsAndCooksFoodQuickly(x) → Microwave(x))                                                                                                                                                                                                                                                                                                                1
# Yes, a possible candidate FOL for the given sentence could be:\n\n∀x (Baker(x) ↔ Person(x) ∧ PreparesBakedGoods(x) ∧ ∃y (Bread(y) ∧ Bakes(x, y))) ∧ ∃z (Pastry(z) ∧ Bakes(x, z)) ∧ ∃w (BakedGood(w) ∧ Bakes(x, w) ∧ VariousTypes(w))\n\nThis formula states that a person is a baker if and only if they are a person, they prepare baked goods, they bake some bread, they bake some pastries, and they bake some baked goods of various types.                                         1
# No\n\nThe candidate FOL formula does not correctly formalize the given sentence. The correct FOL formula should express that every citizen in a democracy has the right to vote and participate, not that the democracy itself has the rights. The correct FOL formula should be:\n\n∀x∀y (Democracy(x) ∧ Citizen(y) ∧ In(y, x) → (RightToVote(y, x) ∧ ParticipateInPoliticalProcess(y, x)))\n\nWhere In(y, x) represents the relationship between a citizen y and the democracy x.      1
# Yes, the candidate FOL is logically equivalent to the true FOL: ∀x (Sport(x) ∧ HasMultiplePlayers(x) ∧ InvolvesCooperation(x) ∧ SharedObjective(x) → TeamSport(x))                                                                                                                                                                                                                                                                                                                       1
# No. The correct FOL should only include the requirement for clearance, not the action of taking off.\n\nCorrect FOL: ∀x (Airplane(x) → NeedsClearanceFromATC(x))                                                                                                                                                                                                                                                                                                                         1
# Yes (for the Candidate FOL)                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# Yes (for the True FOL)\nNo (for the Candidate FOL)                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# No\n\nThe correct FOL for the given sentence should be:\n\nOpen(door) ∨ Closed(window) ∨ Open(window) ∧ Closed(door)\n\nThe candidate FOL you provided is not equivalent to the given sentence, as it does not account for the possibility that both the door and the window can be in opposite states (open and closed, or closed and open). The candidate FOL only covers the cases where either the door or the window is in the same state (either open or closed).                  1
# No\n\nThe candidate FOL formula does not correctly capture the meaning of the given sentence. The sentence states that cacti and palm trees have different adaptations for water storage and conservation, but the formula only mentions adaptations for water storage and conservation for a single entity (x). The formula should be modified to compare adaptations between cacti and palm trees, as in the true FOL formula provided.                                                1
# Yes (Candidate FOL is logically equivalent to the True FOL)                                                                                                                                                                                                                                                                                                                                                                                                                              1
# Name: count, dtype: int64

# %%
##########################
#Funzione che viene usata per processare la colonna 'judge_mistral', in quanto
# contiene valori che non sono coerenti con gli altri, ossia oltre alla risposta Yes/No,
# contiene una piccola explanation.
#########################
def process_mistral(value):
    stripped_value = value.strip()
    stripped_value = stripped_value.translate(str.maketrans('', '', string.punctuation))
    
    split_value = stripped_value.split()
    
    if stripped_value in ['Yes', 'No']:
        return stripped_value
    else:
        return split_value[0] if split_value else stripped_value

dataset_g['judge_mistral'] = dataset_g['judge_mistral'].apply(process_mistral)
dataset_l['judge_mistral'] = dataset_l['judge_mistral'].apply(process_mistral)
dataset_q['judge_mistral'] = dataset_q['judge_mistral'].apply(process_mistral)

# %%
print(dataset_g['judge_mistral'].value_counts())
print("_"*40)
print(dataset_l['judge_mistral'].value_counts())
print("_"*40)
print(dataset_q['judge_mistral'].value_counts())
# Out:
# judge_mistral
# Yes    950
# No      50
# Name: count, dtype: int64
# ________________________________________
# judge_mistral
# Yes    967
# No      33
# Name: count, dtype: int64
# ________________________________________
# judge_mistral
# Yes    988
# No      12
# Name: count, dtype: int64

# %%
#####################################
# FUNZIONI DI PLOT
#####################################
def plot_comparison_graph(dataset, columns, labels=['Yes', 'No'], figsize=(10, 6), bar_width=0.25, title="title", ax=None):
    counts = {col: dataset[col].value_counts() for col in columns}
    totals = {col: counts[col].sum() for col in columns}
    percents = {col: {label: counts[col].get(label, 0) / totals[col] * 100 for label in labels} for col in columns}
    
    values = {col: [counts[col].get('Yes', 0), counts[col].get('No', 0)] for col in columns}

    plt.style.use('seaborn-v0_8-muted')

    if ax is None:
        fig, ax = plt.subplots(figsize=figsize)
    
    x = range(len(labels))

    colors = ['#66C2A5', '#FC8D62', '#8DA0CB']  # Colori per judge_llama, judge_qwen, judge_mistral
    bars = {}
    
    for i, col in enumerate(columns):
        bars[col] = ax.bar(
            [p + i * bar_width for p in x], 
            values[col], 
            width=bar_width, 
            label=col, 
            color=colors[i % len(colors)], 
            align='center', 
            zorder=3
        )

        for bar, label in zip(bars[col], labels):
            ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.05,
                    f'{percents[col][label]:.1f}%', ha='center', va='bottom', fontsize=12, 
                    fontweight='bold', color='black', zorder=4)
    
    ax.set_xlabel('Answer', fontsize=14, fontweight='bold', color='#4C4C4C')
    ax.set_ylabel('Counts', fontsize=14, fontweight='bold', color='#4C4C4C')
    ax.set_title( title,fontsize=16, fontweight='bold', color='#2F4F4F')

    ax.set_xticks([p + bar_width for p in x])
    ax.set_xticklabels(labels, fontsize=12, color='#4C4C4C')

    ax.legend(title="Answer From", title_fontsize=12, fontsize=12, loc='upper right')

    ax.grid(axis='y', linestyle='--', alpha=0.7, zorder=0)

    if ax is None:
        plt.tight_layout()

def plot_ensemble_graph(dataset, columns, new_column_name='judge_ensemble', labels=['Yes', 'No'], figsize=(8, 6), bar_width=0.35, title="title", ax=None):
    
    def ensemble(row):
        # Funzione per simulare un ensemble
        tot_yes = 0
        for col in columns:
            if row[col].lower() == 'yes':
                tot_yes += 1
        if tot_yes > 1:  # Etichetta maggioritaria
            return 'Yes'
        else:
            return 'No'

    dataset[new_column_name] = dataset.apply(ensemble, axis=1)
    ensemble_counts = dataset[new_column_name].value_counts()

    ensemble_total = ensemble_counts.sum()
    ensemble_percent = {
        "Yes": ensemble_counts.get('Yes', 0) / ensemble_total * 100,
        "No": ensemble_counts.get('No', 0) / ensemble_total * 100
    }

    ensemble_values = ensemble_counts.get('Yes', 0), ensemble_counts.get('No', 0)
    x = range(len(labels))

    plt.style.use('seaborn-v0_8-muted')

    if ax is None:
        fig, ax = plt.subplots(figsize=figsize)

    ensemble_bars_yes = ax.bar(x[0], ensemble_values[0], width=bar_width, label='Yes', color='#66C2A5', align='center', zorder=3)
    ensemble_bars_no = ax.bar(x[1] + bar_width, ensemble_values[1], width=bar_width, label='No', color='#FC8D62', align='center', zorder=3)

    for bar, label, percent in zip(ensemble_bars_yes, labels, [ensemble_percent['Yes']]):
        ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.05,
                f'{percent:.1f}%', ha='center', va='bottom', fontsize=12, fontweight='bold', color='black', zorder=4)

    for bar, label, percent in zip(ensemble_bars_no, labels, [ensemble_percent['No']]):
        ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 0.05,
                f'{percent:.1f}%', ha='center', va='bottom', fontsize=12, fontweight='bold', color='black', zorder=4)

    ax.set_xlabel('Answer', fontsize=14, fontweight='bold', color='#4C4C4C')
    ax.set_ylabel('Count', fontsize=14, fontweight='bold', color='#4C4C4C')
    ax.set_title(title, fontsize=16, fontweight='bold', color='#2F4F4F')
    ax.set_xticks([p + bar_width / 2 for p in x])
    ax.set_xticklabels(labels, fontsize=12, color='#4C4C4C')
    ax.legend(title="Types", title_fontsize=12, fontsize=12, loc='upper right')
    ax.grid(axis='y', linestyle='--', alpha=0.7, zorder=0)

    if ax is None:
        plt.tight_layout()

# Funzione per plottare tutti i grafici
def plot_all_graphs(datasets, columns_list, titles_list):
    fig, axs = plt.subplots(3, 2, figsize=(14, 18))  # 3 righe, 2 colonne

    for i, dataset in enumerate(datasets):
        columns = columns_list[i]
        title = titles_list[i]

        plot_comparison_graph(dataset, columns, ax=axs[i, 0], title=f"Comparison {title}")
        plot_ensemble_graph(dataset, columns, ax=axs[i, 1], title=f"Ensemble {title}")
    
    plt.tight_layout()
    plt.show()

# %%
# Funzione per calcolare l'accuratezza come frazione di "Yes" sul totale, molto elementare
def calculate_accuracy_as_yes_fraction(dataset, judge_column):
    yes_count = dataset[judge_column].value_counts().get('Yes', 0)  # Conta il numero di "Yes"
    total_count = len(dataset)
    accuracy = yes_count / total_count
    return accuracy

# %% [markdown]
# # Gemma 2 2B it

# %%
plot_comparison_graph(dataset_g, columns=['judge_llama', 'judge_qwen', 'judge_mistral'],title="Answers from different models for output from Gemma")

# %%
plot_ensemble_graph(dataset_g, columns=['judge_llama', 'judge_qwen', 'judge_mistral'],title="Answers from ensamble of models with output of Gemma ")

# %%
judges = ['judge_llama', 'judge_qwen', 'judge_mistral']
accuracies = {judge: calculate_accuracy_as_yes_fraction(dataset_g, judge) for judge in judges}

average_accuracy = sum(accuracies.values()) / len(accuracies)

print("Accuratezze per ogni giudice (frazione di 'Yes'):")
for judge, accuracy in accuracies.items():
    print(f"{judge}: {accuracy * 100:.2f}%")

print(f"\nAccuratezza media: {average_accuracy * 100:.2f}%")
# Out:
# Accuratezze per ogni giudice (frazione di 'Yes'):
# judge_llama: 61.10%
# judge_qwen: 58.50%
# judge_mistral: 95.00%
#
# Accuratezza media: 71.53%

# %% [markdown]
# # Llama 3.2 3B it

# %%
plot_comparison_graph(dataset_l, columns=['judge_llama', 'judge_qwen', 'judge_mistral'],title="Answers from different models for output from Llama")

# %%
plot_ensemble_graph(dataset_l, columns=['judge_llama', 'judge_qwen', 'judge_mistral'],title="Answers from ensamble of models with output of Llama ")

# %%
judges = ['judge_llama', 'judge_qwen', 'judge_mistral']
accuracies = {judge: calculate_accuracy_as_yes_fraction(dataset_l, judge) for judge in judges}

average_accuracy = sum(accuracies.values()) / len(accuracies)

print("Accuratezze per ogni giudice (frazione di 'Yes'):")
for judge, accuracy in accuracies.items():
    print(f"{judge}: {accuracy * 100:.2f}%")

print(f"\nAccuratezza media: {average_accuracy * 100:.2f}%")
# Out:
# Accuratezze per ogni giudice (frazione di 'Yes'):
# judge_llama: 63.00%
# judge_qwen: 56.10%
# judge_mistral: 96.70%
#
# Accuratezza media: 71.93%

# %% [markdown]
# # Qwen3 4b it

# %%
plot_comparison_graph(dataset_q, columns=['judge_llama', 'judge_qwen', 'judge_mistral'],title="Answers from different models for output from Qwen")

# %%
plot_ensemble_graph(dataset_l, columns=['judge_llama', 'judge_qwen', 'judge_mistral'],title="Answers from ensamble of models with output of Qwen ")

# %%
judges = ['judge_llama', 'judge_qwen', 'judge_mistral']
accuracies = {judge: calculate_accuracy_as_yes_fraction(dataset_q, judge) for judge in judges}

average_accuracy = sum(accuracies.values()) / len(accuracies)

print("Accuratezze per ogni giudice (frazione di 'Yes'):")
for judge, accuracy in accuracies.items():
    print(f"{judge}: {accuracy * 100:.2f}%")

print(f"\nAccuratezza media: {average_accuracy * 100:.2f}%")
# Out:
# Accuratezze per ogni giudice (frazione di 'Yes'):
# judge_llama: 69.40%
# judge_qwen: 68.40%
# judge_mistral: 98.80%
#
# Accuratezza media: 78.87%

# %%
datasets = [dataset_g, dataset_l, dataset_q]
columns_list = [['judge_llama',"judge_qwen",'judge_mistral'], ['judge_llama',"judge_qwen",'judge_mistral'], ['judge_llama',"judge_qwen",'judge_mistral']]  # Colonne da confrontare per ciascun dataset
titles_list = ['Output from Gemma 2 2B - IT', 'Output from LLama 3.1 3B - IT', 'Output from Qwen3 4B - IT']

plot_all_graphs(datasets, columns_list, titles_list)
